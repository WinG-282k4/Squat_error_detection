# %%
import cv2
import os

def extract_frames(video_path, output_folder, start_frame_count):
    """
    Trích xuất các khung hình từ video và lưu chúng dưới dạng các tệp ảnh riêng biệt.

    Args:
    video_path (str): Đường dẫn đến video đầu vào.
    output_folder (str): Thư mục để lưu các khung hình đã trích xuất.
    start_frame_count (int): Số thứ tự khung hình bắt đầu.
    """
    # Tạo thư mục để lưu các khung hình nếu chưa tồn tại
    os.makedirs(output_folder, exist_ok=True)

    # Mở video
    cap = cv2.VideoCapture(video_path)

    frame_count = start_frame_count

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        # Đường dẫn để lưu khung hình
        frame_filename = os.path.join(output_folder, f'Dau_goi_hep_{frame_count:04d}.jpg')
        
        # Lưu khung hình
        cv2.imwrite(frame_filename, frame)
        
        frame_count += 1

    # Giải phóng tài nguyên
    cap.release()
    cv2.destroyAllWindows()

    print(f'Extracted {frame_count - start_frame_count} frames from {video_path} to {output_folder}')
    return frame_count

def extract_frames_from_folder(video_folder, output_folder):
    """
    Trích xuất các khung hình từ tất cả các video trong một thư mục và lưu chúng vào một thư mục duy nhất.

    Args:
    video_folder (str): Thư mục chứa các video đầu vào.
    output_folder (str): Thư mục để lưu các khung hình đã trích xuất.
    """
    frame_count = 0
    # Lặp qua tất cả các tệp trong thư mục video
    for video_filename in os.listdir(video_folder):
        video_path = os.path.join(video_folder, video_filename)
        
        # Kiểm tra xem tệp có phải là video không
        if os.path.isfile(video_path) and video_path.endswith(('.mp4', '.avi', '.mov', '.mkv')):
            frame_count = extract_frames(video_path, output_folder, frame_count)

# Sử dụng hàm để trích xuất khung hình từ tất cả các video trong thư mục
video_folder = 'Data/Train/Dau_goi_hep'
output_folder = 'Data/Train/Dau_goi_hep_frames'
extract_frames_from_folder(video_folder, output_folder)

video_folder = 'Data/Validation/Dau_goi_hep'
output_folder = 'Data/Validation/Dau_goi_hep_frames'
extract_frames_from_folder(video_folder, output_folder)

video_folder = 'Data/Test/Dau_goi_hep'
output_folder = 'Data/Test/Dau_goi_hep_frames'
extract_frames_from_folder(video_folder, output_folder)
# Out:
# Extracted 89 frames from Data/Train/Dau_goi_hep\Video.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 123 frames from Data/Train/Dau_goi_hep\Video1.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 67 frames from Data/Train/Dau_goi_hep\Video2.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 98 frames from Data/Train/Dau_goi_hep\Video3.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 66 frames from Data/Train/Dau_goi_hep\Video4.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 114 frames from Data/Train/Dau_goi_hep\Video5.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 53 frames from Data/Train/Dau_goi_hep\Video_1.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 50 frames from Data/Train/Dau_goi_hep\Video_10.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 37 frames from Data/Train/Dau_goi_hep\Video_11.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 80 frames from Data/Train/Dau_goi_hep\Video_12.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 81 frames from Data/Train/Dau_goi_hep\Video_13.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 91 frames from Data/Train/Dau_goi_hep\Video_16.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 83 frames from Data/Train/Dau_goi_hep\Video_17.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 65 frames from Data/Train/Dau_goi_hep\Video_18.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 65 frames from Data/Train/Dau_goi_hep\Video_2.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 73 frames from Data/Train/Dau_goi_hep\Video_20.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 65 frames from Data/Train/Dau_goi_hep\Video_24.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 47 frames from Data/Train/Dau_goi_hep\Video_25.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 87 frames from Data/Train/Dau_goi_hep\Video_26.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 55 frames from Data/Train/Dau_goi_hep\Video_27.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 68 frames from Data/Train/Dau_goi_hep\Video_28.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 70 frames from Data/Train/Dau_goi_hep\Video_29.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 46 frames from Data/Train/Dau_goi_hep\Video_3.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 54 frames from Data/Train/Dau_goi_hep\Video_30.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 72 frames from Data/Train/Dau_goi_hep\Video_4.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 37 frames from Data/Train/Dau_goi_hep\Video_5.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 60 frames from Data/Train/Dau_goi_hep\Video_6.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 84 frames from Data/Train/Dau_goi_hep\Video_7.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 62 frames from Data/Train/Dau_goi_hep\Video_8.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 69 frames from Data/Train/Dau_goi_hep\Video_9.mp4 to Data/Train/Dau_goi_hep_frames
# Extracted 54 frames from Data/Validation/Dau_goi_hep\Video_10.mp4 to Data/Validation/Dau_goi_hep_frames
# Extracted 69 frames from Data/Validation/Dau_goi_hep\Video_14.mp4 to Data/Validation/Dau_goi_hep_frames
# Extracted 60 frames from Data/Validation/Dau_goi_hep\Video_15.mp4 to Data/Validation/Dau_goi_hep_frames
# Extracted 66 frames from Data/Validation/Dau_goi_hep\Video_19.mp4 to Data/Validation/Dau_goi_hep_frames
# Extracted 84 frames from Data/Validation/Dau_goi_hep\Video_2.mp4 to Data/Validation/Dau_goi_hep_frames
# Extracted 64 frames from Data/Validation/Dau_goi_hep\Video_21.mp4 to Data/Validation/Dau_goi_hep_frames
# Extracted 72 frames from Data/Validation/Dau_goi_hep\Video_22.mp4 to Data/Validation/Dau_goi_hep_frames
# Extracted 57 frames from Data/Validation/Dau_goi_hep\Video_23.mp4 to Data/Validation/Dau_goi_hep_frames
# Extracted 82 frames from Data/Validation/Dau_goi_hep\Video_3.mp4 to Data/Validation/Dau_goi_hep_frames
# Extracted 55 frames from Data/Validation/Dau_goi_hep\Video_7.mp4 to Data/Validation/Dau_goi_hep_frames
# Extracted 60 frames from Data/Test/Dau_goi_hep\Video_1.mp4 to Data/Test/Dau_goi_hep_frames
# Extracted 56 frames from Data/Test/Dau_goi_hep\Video_10.mp4 to Data/Test/Dau_goi_hep_frames
# Extracted 63 frames from Data/Test/Dau_goi_hep\Video_2.mp4 to Data/Test/Dau_goi_hep_frames
# Extracted 53 frames from Data/Test/Dau_goi_hep\Video_3.mp4 to Data/Test/Dau_goi_hep_frames
# Extracted 52 frames from Data/Test/Dau_goi_hep\Video_4.mp4 to Data/Test/Dau_goi_hep_frames
# Extracted 8 frames from Data/Test/Dau_goi_hep\Video_5.mp4 to Data/Test/Dau_goi_hep_frames
# Extracted 13 frames from Data/Test/Dau_goi_hep\Video_6.mp4 to Data/Test/Dau_goi_hep_frames
# Extracted 17 frames from Data/Test/Dau_goi_hep\Video_7.mp4 to Data/Test/Dau_goi_hep_frames
# Extracted 28 frames from Data/Test/Dau_goi_hep\Video_8.mp4 to Data/Test/Dau_goi_hep_frames
# Extracted 19 frames from Data/Test/Dau_goi_hep\Video_9.mp4 to Data/Test/Dau_goi_hep_frames
